# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Dataset\healthcare_dataset.csv')

# %%
df
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0       Bryan Erickson   53    Male        AB+         Arthritis
# 1     Rhonda Hernandez   65  Female        AB+         Arthritis
# 2           Corey Rose   31  Female         A+      Hypertension
# 3        John Williams   54    Male         O+         Arthritis
# 4        Denise Norman   73  Female        AB+            Asthma
# ...                ...  ...     ...        ...               ...
# 9995     Sierra Moreno   43  Female        AB+            Cancer
# 9996      Frank Lester   58    Male        AB+            Asthma
# 9997        Drew Jones   46    Male        AB+            Asthma
# 9998       Joel Lawson   45  Female         A-      Hypertension
# 9999      Nicole Casey   43    Male         B+           Obesity
#
#      Date of Admission          Doctor                     Hospital Hospitals  \
# 0             01-03-22    Jon Robinson                   Abbott Inc         A
# ...

# %%
df.shape
# Out:
# (10000, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Hospitals           10000 non-null  object
#  9   Insurance Provider  10000 non-null  object
#  10  Billing Amount      10000 non-null  float64
#  11  Room Number         10000 non-null  int64
#  12  Admission Type      10000 non-null  object
#  13  Discharge Date      10000 non-null  object
#  14  Medication          10000 non-null  object
# ...

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'],format='%d-%m-%y')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'],format='%d-%m-%y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  datetime64[ns]
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Hospitals           10000 non-null  object
#  9   Insurance Provider  10000 non-null  object
#  10  Billing Amount      10000 non-null  float64
#  11  Room Number         10000 non-null  int64
#  12  Admission Type      10000 non-null  object
#  13  Discharge Date      10000 non-null  datetime64[ns]
#  14  Medication          10000 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Hospitals             0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# year of admission     0
# Days of stay          0
# age group             0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age           Date of Admission  Billing Amount   Room Number  \
# count  10000.000000                       10000    10000.000000  10000.000000
# mean      51.452200  2021-05-01 21:53:25.440000    25516.806778    300.082000
# min       18.000000         2018-10-30 00:00:00     1000.180837    101.000000
# 25%       35.000000         2020-02-10 00:00:00    13506.523967    199.000000
# 50%       52.000000         2021-05-02 00:00:00    25258.112565    299.000000
# 75%       68.000000         2022-07-23 06:00:00    37733.913725    400.000000
# max       85.000000         2023-10-30 00:00:00    49995.902280    500.000000
# std       19.588974                         NaN    14067.292709    115.806027
#
#                    Discharge Date  year of admission  Days of stay
# count                       10000        10000.00000  10000.000000
# mean   2021-05-17 11:22:24.960000         2020.83340     15.561800
# ...

# %%
Total_Patients = df.shape[0]
print("Total Patients:", Total_Patients)
# Out:
# Total Patients: 10000

# %%
gender_counts = df['Gender'].value_counts()

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Male and Female Distribution')
plt.axis('equal')
plt.show()

# %%
medical_condition_counts = df['Medical Condition'].value_counts()

top_3_medical_conditions = medical_condition_counts.nlargest(3)

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_3_medical_conditions, labels=top_3_medical_conditions.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 3 Medical Conditions')
plt.axis('equal')  
plt.show()

# %%
admission_type_counts = df['Admission Type'].value_counts()

top_3_admission_types = admission_type_counts.nlargest(3)

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_3_admission_types, labels=top_3_admission_types.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 3 Admission Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
blood_type_distribution = df['Blood Type'].value_counts()

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(blood_type_distribution, labels=blood_type_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Blood Type Distribution')
plt.axis('equal') 
plt.show()

# %%
patient_counts = df.groupby('year of admission').size()
average_patients_per_year = patient_counts.mean()
print("Average Patients Per Year:", average_patients_per_year)
# Out:
# Average Patients Per Year: 1666.6666666666667

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
max_date_of_admission = df['Date of Admission'].max()
filtered_data = df[df['Date of Admission'] <= max_date_of_admission]
filtered_data = filtered_data[filtered_data['Date of Admission'].dt.year == max_date_of_admission.year]
result = len(filtered_data)
print("Count:", result)
# Out:
# Count: 1616

# %%
total_doctors = df['Doctor'].nunique()

print("Total Doctors:", total_doctors)
# Out:
# Total Doctors: 9416

# %%
total_hospitals = df['Hospital'].nunique()

print("Total Hospitals:", total_hospitals)
# Out:
# Total Hospitals: 8639

# %%
total_count = len(df)

age_group_counts = df['age group'].value_counts()
percentage_per_age_group = (age_group_counts * 100.0) / total_count

result = pd.DataFrame({'age group': age_group_counts.index, 'Percentage': percentage_per_age_group}).reset_index(drop=True)

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(result['Percentage'], labels=result['age group'], autopct='%1.1f%%', startangle=140)
plt.title('Age Group Distribution')
plt.axis('equal')  
plt.show()

# %%
young_patients_count = df[df['age group'] == 'Young'].shape[0]

print("Young Patients Count:", young_patients_count)
# Out:
# Young Patients Count: 1774

# %%
young_male_patients_count = df[(df['age group'] == 'Young') & (df['Gender'] == 'Male')].shape[0]

print("Young Male Patients Count:", young_male_patients_count)
# Out:
# Young Male Patients Count: 867

# %%
young_female_patients_count = df[(df['age group'] == 'Young') & (df['Gender'] == 'Female')].shape[0]

print("Young Female Patients Count:", young_female_patients_count)
# Out:
# Young Female Patients Count: 907

# %%
young_patients_df = df[df['age group'] == 'Young']
top_3_medical_conditions_in_young = young_patients_df.groupby('Medical Condition').size().nlargest(3).reset_index(name='Top_3_Medical_Condition_in_Young')

plt.figure(figsize=(8, 6))
plt.pie(top_3_medical_conditions_in_young['Top_3_Medical_Condition_in_Young'], labels=top_3_medical_conditions_in_young['Medical Condition'], autopct='%1.1f%%', startangle=140)
plt.title('Top 3 Medical Conditions in Young Patients')
plt.axis('equal') 
plt.show()

# %%
young_patients_df = df[df['age group'] == 'Young']
top_admission_types_in_young = young_patients_df.groupby('Admission Type').size().nlargest(3).reset_index(name='TopAdmission_Type_in_Young')

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_admission_types_in_young['TopAdmission_Type_in_Young'], labels=top_admission_types_in_young['Admission Type'], autopct='%1.1f%%', startangle=140)
plt.title('Top Admission Types in Young Patients')
plt.axis('equal')
plt.show()

# %%
young_patients_df = df[df['age group'] == 'Young']
top_test_results_in_young = young_patients_df.groupby('Test Results').size().nlargest(3).reset_index(name='TopResults_in_Young')

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_test_results_in_young['TopResults_in_Young'], labels=top_test_results_in_young['Test Results'], autopct='%1.1f%%', startangle=140)
plt.title('Top Test Results in Young Patients')
plt.axis('equal')  
plt.show()

# %%
adult_patients_count = df[df['age group'] == 'Adult'].shape[0]
print("Adult Patients Count:", adult_patients_count)
# Out:
# Adult Patients Count: 4413

# %%
adult_male_patients_count = df[(df['age group'] == 'Adult') & (df['Gender'] == 'Male')].shape[0]
print("Adult Male Patients Count:", adult_male_patients_count)
# Out:
# Adult Male Patients Count: 2203

# %%
adult_female_patients_count = df[(df['age group'] == 'Adult') & (df['Gender'] == 'Female')].shape[0]
print("Adult Female Patients Count:", adult_female_patients_count)
# Out:
# Adult Female Patients Count: 2210

# %%
adult_patients_df = df[df['age group'] == 'Adult']
top_3_medical_conditions_in_adult = adult_patients_df.groupby('Medical Condition').size().nlargest(3).reset_index(name='Top_3_Medical_Condition_in_Adult')

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_3_medical_conditions_in_adult['Top_3_Medical_Condition_in_Adult'], labels=top_3_medical_conditions_in_adult['Medical Condition'], autopct='%1.1f%%', startangle=140)
plt.title('Top 3 Medical Conditions in Adult Patients')
plt.axis('equal')
plt.show()

# %%
adult_patients_df = df[df['age group'] == 'Adult']
top_admission_types_in_adult = adult_patients_df.groupby('Admission Type').size().nlargest(3).reset_index(name='TopAdmission_Type_inAdult')

plt.figure(figsize=(8, 6))
plt.pie(top_admission_types_in_adult['TopAdmission_Type_inAdult'], labels=top_admission_types_in_adult['Admission Type'], autopct='%1.1f%%', startangle=140)
plt.title('Top Admission Types in Adult Patients')
plt.axis('equal')
plt.show()

# %%
adult_patients_df = df[df['age group'] == 'Adult']
top_test_results_in_adult = adult_patients_df.groupby('Test Results').size().nlargest(3).reset_index(name='TopResults_in_Adult')

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_test_results_in_adult['TopResults_in_Adult'], labels=top_test_results_in_adult['Test Results'], autopct='%1.1f%%', startangle=140)
plt.title('Top Test Results in Adult Patients')
plt.axis('equal')
plt.show()

# %%
senior_patients_count = df[df['age group'] == 'Senior'].shape[0]
print("Senior Patients Count:", senior_patients_count)
# Out:
# Senior Patients Count: 3813

# %%
senior_male_patients_count = df[(df['age group'] == 'Senior') & (df['Gender'] == 'Male')].shape[0]

print("Senior Male Patients Count:", senior_male_patients_count)
# Out:
# Senior Male Patients Count: 1855

# %%
senior_female_patients_count = df[(df['age group'] == 'Senior') & (df['Gender'] == 'Female')].shape[0]

print("Senior Female Patients Count:", senior_female_patients_count)
# Out:
# Senior Female Patients Count: 1958

# %%
senior_patients_df = df[df['age group'] == 'Senior']
top_3_medical_conditions_in_senior = senior_patients_df.groupby('Medical Condition').size().nlargest(3).reset_index(name='Top_3_Medical_Condition_in_Senior')

# Plotting a pie chart
plt.figure(figsize=(8, 6))
plt.pie(top_3_medical_conditions_in_senior['Top_3_Medical_Condition_in_Senior'], labels=top_3_medical_conditions_in_senior['Medical Condition'], autopct='%1.1f%%', startangle=140)
plt.title('Top 3 Medical Conditions in Senior Patients')
plt.axis('equal') 
plt.show()

# %%
senior_patients_df = df[df['age group'] == 'Senior']
top_admission_types_in_senior = senior_patients_df.groupby('Admission Type').size().nlargest(3).reset_index(name='TopAdmission_Type_in_Senior')

plt.figure(figsize=(8, 6))
plt.pie(top_admission_types_in_senior['TopAdmission_Type_in_Senior'], labels=top_admission_types_in_senior['Admission Type'], autopct='%1.1f%%', startangle=140)
plt.title('Top Admission Types in Senior Patients')
plt.axis('equal')
plt.show()

# %%
senior_patients_df = df[df['age group'] == 'Senior']
top_test_results_in_senior = senior_patients_df.groupby('Test Results').size().nlargest(3).reset_index(name='TopResults_in_Senior')

plt.figure(figsize=(8, 6))
plt.pie(top_test_results_in_senior['TopResults_in_Senior'], labels=top_test_results_in_senior['Test Results'], autopct='%1.1f%%', startangle=140)
plt.title('Top Test Results in Senior Patients')
plt.axis('equal') 
plt.show()

# %%
average_days_of_stay = df['Days of stay'].mean()

print("Average Days of Stay:", average_days_of_stay)
# Out:
# Average Days of Stay: 15.5618

# %%
average_per_day_charge = (df['Billing Amount'] / df['Days of stay']).mean()

print("Average Per Day Charge:", average_per_day_charge)
# Out:
# Average Per Day Charge: 3321.2003774386826

# %%
total_revenue = df['Billing Amount'].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 255168067.777717
